# %% [markdown]
# #Exploração e Narrativa de Dados (Monitoramento IoT)
# #Carregamento de arquivo JSON, diagnóstico de dados ("sujeira"), tratamento de valores ausentes e criação de uma narrativa baseada nos resultados.
# #Analise de dados de uma estufa inteligente. O sensor de temperatura falhou algumas vezes, registrando valores nulos (null). Seu objetivo é tratar esses dados e explicar o que aconteceu.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_json('sensores.json')
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   hora       10 non-null     str
#  1   sensor_id  10 non-null     str
#  2   temp       7 non-null      float64
# dtypes: float64(1), str(2)
# memory usage: 372.0 bytes
